# %% [markdown]
# # 001 Importing the Dependencies

# %%
# Import pandas package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # 002 Data Collection and Processing

# %%
# Loading data to pandas DataFrame
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# loading csv File
file_path = '/content/drive/MyDrive/Colab Notebooks/ML_Practice_Projects/Project 10 Logistic Regression Credit Card fraud detection/creditcard.csv'
credit_card_data=pd.read_csv(file_path)
pd.set_option('display.max_columns',None)

# %%
credit_card_data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# ...

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
credit_card_data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
credit_card_data.shape
# Out:
# (284807, 31)

# %%
credit_card_data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# Checking the missing in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Distribution of legit vs fraudalent transaction
credit_card_data.Class.value_counts()
# Hence this is a case of class unbalance
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# # 'Class' Column
# 0---->>> Normal Transaction
#
# 1---->>> Fraud Transaction

# %% [markdown]
# # Separating the data for analysis

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
# Out:
# (284315, 31)

# %%
print(fraud.shape)
# Out:
# (492, 31)

# %%
# Statistical measures of the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# Compare the values for both transaction
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9       V10       V11       V12  \
# Class
# 0      0.002419  0.009637 -0.000987  0.004467  0.009824 -0.006576  0.010832
# 1     -1.397737 -5.568731  0.570636 -2.581123 -5.676883  3.800173 -6.259393
#
#             V13       V14       V15       V16       V17       V18       V19  \
# Class
# 0      0.000189  0.012064  0.000161  0.007164  0.011535  0.003887 -0.001178
# 1     -0.109334 -6.971723 -0.092929 -4.139946 -6.665836 -2.246308  0.680659
#
#             V20       V21       V22       V23       V24       V25       V26  \
# Class
# 0     -0.000644 -0.001235 -0.000024  0.000070  0.000182 -0.000072 -0.000089
# 1      0.372319  0.713588  0.014049 -0.040308 -0.105130  0.041449  0.051648
#
# ...

# %% [markdown]
# # Dealing with the unbalance dataset
# Build a sample dataset containing similar distribution of normal transaction and fraudulent transaction

# %% [markdown]
# No of fraudulent transactions ----->>>> 'Class'= 1----->>>>>> 492

# %%
legit_sample = legit.sample(n=492)

# %%
fraud
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %% [markdown]
# Concatenating two dataframes

# %%
# new_dataset = legit_sample + fraud

# %%
# new_dataset.shape
# Out:
# (984, 31)

# %%
new_dataset = pd.concat([legit_sample,fraud], axis=0)
new_dataset.shape
# Both are same things
# Out:
# (984, 31)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 262269  160389.0  1.235299 -2.205981 -0.869290  0.041260 -1.708123 -0.769398
# 127012   78179.0 -2.097999  1.187217  0.182980 -0.042259  0.435664 -1.636035
# 197663  132121.0  2.034747 -0.314437 -0.804101 -0.012814  0.090146  0.485639
# 275925  166796.0 -1.475351  1.524470 -0.556839 -2.800303  0.566934 -0.527291
# 95301    65245.0  0.108802  1.116435 -0.021038  1.071929  0.479185  0.626870
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 262269 -0.220290 -0.190043 -0.415382  0.839271  1.043957  0.617886 -0.337200
# 127012  0.034385  0.770432 -1.228463 -1.586941  1.463477  0.291357 -0.866429
# 197663 -0.635463  0.133622  0.901374  0.039499  0.248716  1.251587  1.224699
# 275925  0.498859  0.843458 -0.414501 -1.225807  0.119741  1.274102  0.774695
# 95301  -0.562241 -2.679082 -1.246032 -0.337342  0.336223  0.772265  0.105439
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 279863 -0.882850  0.697211 -2.064945 -5.587794  2.115795 -5.417424 -1.235123
# 280143 -1.413170  0.248525 -1.127396 -3.232153  2.858466 -3.096915 -0.792532
# 280149 -2.234739  1.210158 -0.652250 -3.463891  1.794969 -2.775022 -0.418950
# 281144 -2.208002  1.058733 -1.632333 -5.245984  1.933520 -5.030465 -1.127455
# 281674  0.223050 -0.068384  0.577829 -0.888722  0.491140  0.728903  0.380428
#
# ...

# %%
new_dataset.Class.value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94208.979675  0.099435 -0.053759  0.114238 -0.008526 -0.033256
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9       V10       V11       V12  \
# Class
# 0     -0.014775  0.019977  0.047498  0.117535  0.021207  0.038243 -0.068904
# 1     -1.397737 -5.568731  0.570636 -2.581123 -5.676883  3.800173 -6.259393
#
#             V13       V14       V15       V16       V17       V18       V19  \
# Class
# 0      0.080382  0.003613 -0.034511  0.037955 -0.009403  0.024224 -0.028667
# 1     -0.109334 -6.971723 -0.092929 -4.139946 -6.665836 -2.246308  0.680659
#
#             V20       V21       V22       V23       V24       V25       V26  \
# Class
# 0      0.020253 -0.027583  0.026190  0.016163 -0.011523  0.004138  0.033907
# 1      0.372319  0.713588  0.014049 -0.040308 -0.105130  0.041449  0.051648
#
# ...

# %% [markdown]
# # Splitting the data into Features and Target

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
print(Y)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 262269  160389.0  1.235299 -2.205981 -0.869290  0.041260 -1.708123 -0.769398
# 127012   78179.0 -2.097999  1.187217  0.182980 -0.042259  0.435664 -1.636035
# 197663  132121.0  2.034747 -0.314437 -0.804101 -0.012814  0.090146  0.485639
# 275925  166796.0 -1.475351  1.524470 -0.556839 -2.800303  0.566934 -0.527291
# 95301    65245.0  0.108802  1.116435 -0.021038  1.071929  0.479185  0.626870
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %% [markdown]
# # Spit the data into training data and testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape,X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
print(Y.shape, Y_train.shape,Y_test.shape)
# Out:
# (984,) (787,) (197,)

# %% [markdown]
# # Training a Model
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the logistic regression model with training data
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Model Evaluation
# ## Checking Accuracy of Model

# %%
# Checking accuracy on training data
X_train_prediction = model.predict(X_train)
X_train_prediction

# Accuracy Score
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)
print("Accuracy on training data is ", training_data_accuracy)
# Out:
# Accuracy on training data is  0.9339263024142312

# %%
# Checking accuracy on test data
X_test_prediction = model.predict(X_test)
X_test_prediction

# Accuracy Score
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)
print("Accuracy on training data is ", test_data_accuracy)
# Out:
# Accuracy on training data is  0.8934010152284264
